# %% [markdown]
# # ELN: Gentoo Penguin Biometrics Analysis
#
# **Experiment ID:** EXP-2026-PENGUIN-003-Gentoo
# **Operator:** Dr. Maria Okonkwo
# **Date:** 2026-02-06
# **Institution:** University of Cape Town, Marine Biology Lab
#
# This notebook analyzes biometric measurements of Adelie penguins including culmen length, culmen depth, flipper length, and body mass, stratified by sex and island location.

# %%
import json
from datetime import datetime
import pandas as pd
import numpy as np

experiment_metadata = {
    'experiment_id': 'EXP-2026-PENGUIN-003-Gentoo',
    'species': 'Gentoo',
    'project': 'Penguin-Biometrics-Analysis',
    'date_started': '2026-02-06',
    'date_completed': '2026-02-06',
    'operator': 'Dr. Maria Okonkwo',
    'supervisor': 'Prof. David Chen',
    'institution': 'University of Cape Town, Marine Biology Lab',
    'objective': 'Analyze biometric measurements (culmen, flipper, mass) of Adelie penguins across islands and sexes',
    'hypothesis': 'Biometric measures vary significantly by sex and island location within the species',
    'data_source': 'Palmer Penguins dataset',
    'data_source_file': 'penguins_Gentoo.csv',
}

print("Experiment metadata loaded:")
print(f"  Experiment ID: {experiment_metadata['experiment_id']}")
print(f"  Species: {experiment_metadata['species']}")
print(f"  Operator: {experiment_metadata['operator']}")
print(f"  Data Source: {experiment_metadata['data_source_file']}")
# Out:
# Experiment metadata loaded:
#   Experiment ID: EXP-2026-PENGUIN-003-Gentoo
#   Species: Gentoo
#   Operator: Dr. Maria Okonkwo
#   Data Source: penguins_Gentoo.csv

# %% [markdown]
# ## Data Loading
#
# Load raw biometric measurements from the Adelie-specific CSV file.

# %%
df_raw = pd.read_csv("penguins_Gentoo.csv")
print(f"Loaded {len(df_raw)} specimens of Adelie penguins")
print(f"\nData preview:")
print(df_raw.head(10))
# Out:
# Loaded 30 specimens of Adelie penguins
#
# Data preview:
#   species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Gentoo  Biscoe              51.3             14.2              231.0
# 1  Gentoo  Biscoe              50.0             16.3              230.0
# 2  Gentoo  Biscoe              50.4             15.3              224.0
# 3  Gentoo  Biscoe              50.7             19.7              223.0
# 4  Gentoo  Biscoe              50.1             16.4              224.0
# 5  Gentoo  Biscoe              49.5             16.2              229.0
# 6  Gentoo  Biscoe              50.4             15.8              220.0
# 7  Gentoo  Biscoe              50.0             16.3              230.0
# 8  Gentoo  Biscoe              50.4             14.2              231.0
# 9  Gentoo  Biscoe              50.7             15.0              227.0
#
#    body_mass_g     sex
# 0       4850.0    Male
# 1       4700.0    Male
# 2       4400.0  Female
# 3       4500.0    Male
# 4       4350.0  Female
# 5       4600.0    Male
# 6       4200.0  Female
# 7       4700.0    Male
# 8       4850.0    Male
# 9       4600.0    Male

# %% [markdown]
# ## Data Quality Check

# %%
print(f"Columns: {list(df_raw.columns)}")
print(f"\nData shape: {df_raw.shape}")
# Out:
# Columns: ['species', 'island', 'culmen_length_mm', 'culmen_depth_mm', 'flipper_length_mm', 'body_mass_g', 'sex']
#
# Data shape: (30, 7)

# %%
print(f"Missing values:\n{df_raw.isnull().sum()}")
# Out:
# Missing values:
# species              0
# island               0
# culmen_length_mm     0
# culmen_depth_mm      0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %% [markdown]
# ### Data Vocabulary Check

# %%
from data_quality import validate_with_vocabulary, clean_errors_and_warnings

# %%
df, report = validate_with_vocabulary(data_path = "penguins_Gentoo.csv", vocab_path= "penguin_vocabulary.csv")

# %%
print("Row count:", report["row_count"])
print("Errors:", report["errors"])
print("Warnings:", report["warnings"])
# Out:
# Row count: 30
# Errors: []
# Warnings: []

# %%
clean_df, info = clean_errors_and_warnings(df, report, method="remove")
info
# Out:
# {'rows_removed': 0,
#  'rows_remaining': 30,
#  'columns_cleaned': ['species',
#   'island',
#   'sex',
#   'culmen_length_mm',
#   'culmen_depth_mm',
#   'flipper_length_mm',
#   'body_mass_g'],
#  'mode': 'remove'}

# %%
print(f"After cleaning there is {len(clean_df)} specimens of Gentoo penguins")
# Out:
# After cleaning there is 30 specimens of Gentoo penguins

# %%
clean_df
# Out:
#    species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0   Gentoo  Biscoe              51.3             14.2              231.0
# 1   Gentoo  Biscoe              50.0             16.3              230.0
# 2   Gentoo  Biscoe              50.4             15.3              224.0
# 3   Gentoo  Biscoe              50.7             19.7              223.0
# 4   Gentoo  Biscoe              50.1             16.4              224.0
# 5   Gentoo  Biscoe              49.5             16.2              229.0
# 6   Gentoo  Biscoe              50.4             15.8              220.0
# 7   Gentoo  Biscoe              50.0             16.3              230.0
# 8   Gentoo  Biscoe              50.4             14.2              231.0
# 9   Gentoo  Biscoe              50.7             15.0              227.0
# 10  Gentoo  Biscoe              50.8             15.7              228.0
# 11  Gentoo  Biscoe              50.3             15.8              219.0
# 12  Gentoo  Biscoe              50.3             15.0              228.0
# 13  Gentoo  Biscoe              50.2             14.3              214.0
# 14  Gentoo  Biscoe              50.8             15.7              228.0
# 15  Gentoo  Biscoe              50.5             15.8              230.0
# 16  Gentoo  Biscoe              49.5             15.2              224.0
# 17  Gentoo  Biscoe              50.8             16.0              228.0
# 18  Gentoo  Biscoe              50.0             15.9              228.0
# 19  Gentoo  Biscoe              49.4             15.8              220.0
# 20  Gentoo  Biscoe              50.7             15.0              223.0
# 21  Gentoo  Biscoe              50.1             15.1              225.0
# 22  Gentoo  Biscoe              50.6             15.9              228.0
# 23  Gentoo  Biscoe              50.5             15.9              222.0
# 24  Gentoo  Biscoe              50.0             15.0              220.0
# 25  Gentoo  Biscoe              50.4             15.3              224.0
# 26  Gentoo  Biscoe              50.7             15.3              230.0
# 27  Gentoo  Biscoe              50.3             15.7              226.0
# 28  Gentoo  Biscoe              50.4             15.1              225.0
# 29  Gentoo  Biscoe              50.0             16.0              230.0
#
#     body_mass_g     sex
# 0        4850.0    Male
# 1        4700.0    Male
# 2        4400.0  Female
# 3        4500.0    Male
# 4        4350.0  Female
# 5        4600.0    Male
# 6        4200.0  Female
# 7        4700.0    Male
# 8        4850.0    Male
# 9        4600.0    Male
# 10       4700.0    Male
# 11       4450.0  Female
# 12       4600.0    Male
# 13       4400.0  Female
# 14       4700.0    Male
# 15       4800.0    Male
# 16       4350.0  Female
# 17       4875.0    Male
# 18       4725.0    Male
# 19       4273.0  Female
# 20       4500.0  Female
# 21       4400.0    Male
# 22       4300.0  Female
# 23       4321.0  Female
# 24       4150.0  Female
# 25       4400.0  Female
# 26       4750.0    Male
# 27       4750.0    Male
# 28       4750.0    Male
# 29       5000.0    Male

# %% [markdown]
# ## Analysis: Descriptive Statistics

# %%
# Overall statistics
print("=" * 70)
print("OVERALL STATISTICS - GENTOO PENGUINS")
print("=" * 70)
print(clean_df[['culmen_length_mm', 'culmen_depth_mm', 'flipper_length_mm', 'body_mass_g']].describe())

# Statistics by sex
print("\n" + "=" * 70)
print("STATISTICS BY SEX")
print("=" * 70)
print(clean_df.groupby('sex')[['culmen_length_mm', 'culmen_depth_mm', 'flipper_length_mm', 'body_mass_g']].describe())

# Statistics by island
print("\n" + "=" * 70)
print("STATISTICS BY ISLAND")
print("=" * 70)
print(clean_df.groupby('island')[['culmen_length_mm', 'culmen_depth_mm', 'flipper_length_mm', 'body_mass_g']].describe())
# Out:
# ======================================================================
# OVERALL STATISTICS - GENTOO PENGUINS
# ======================================================================
#        culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# count         30.000000        30.000000          30.000000    30.000000
# mean          50.326667        15.630000         225.633333  4564.800000
# std            0.424210         0.974202           4.205771   223.710774
# min           49.400000        14.200000         214.000000  4150.000000
# 25%           50.025000        15.100000         223.250000  4400.000000
# 50%           50.400000        15.700000         226.500000  4600.000000
# 75%           50.675000        15.900000         228.750000  4743.750000
# max           51.300000        19.700000         231.000000  5000.000000
#
# ======================================================================
# STATISTICS BY SEX
# ======================================================================
#        culmen_length_mm                                                    \
#                   count       mean       std   min     25%    50%     75%
# sex
# Female             12.0  50.208333  0.405549  49.4  50.075  50.35  50.425
# Male               18.0  50.405556  0.429051  49.5  50.025  50.40  50.700
#
#              culmen_depth_mm             ... flipper_length_mm         \
#          max           count       mean  ...               75%    max
# sex                                      ...
# Female  50.7            12.0  15.475000  ...             224.0  228.0
# Male    51.3            18.0  15.733333  ...             230.0  231.0
#
#        body_mass_g                                                            \
#              count         mean         std     min      25%     50%     75%
# sex
# Female        12.0  4341.166667  100.378224  4150.0  4293.25  4350.0  4400.0
# Male          18.0  4713.888889  141.479115  4400.0  4625.00  4712.5  4787.5
#
#
#            max
# sex
# Female  4500.0
# Male    5000.0
#
# [2 rows x 32 columns]
#
# ======================================================================
# STATISTICS BY ISLAND
# ======================================================================
#        culmen_length_mm                                                        \
#                   count       mean      std   min     25%   50%     75%   max
# island
# Biscoe             30.0  50.326667  0.42421  49.4  50.025  50.4  50.675  51.3
#
#        culmen_depth_mm         ... flipper_length_mm        body_mass_g  \
#                  count   mean  ...               75%    max       count
# island                         ...
# Biscoe            30.0  15.63  ...            228.75  231.0        30.0
#
#
#           mean         std     min     25%     50%      75%     max
# island
# Biscoe  4564.8  223.710774  4150.0  4400.0  4600.0  4743.75  5000.0
#
# [1 rows x 32 columns]

# %%
# Calculate analysis results for export
analysis_results = {
    'species': experiment_metadata['species'],
    'specimen_count': len(clean_df),
    'specimen_by_sex': clean_df['sex'].value_counts().to_dict(),
    'specimen_by_island': clean_df['island'].value_counts().to_dict(),
    'mean_body_mass_g': float(clean_df['body_mass_g'].mean()),
    'std_body_mass_g': float(clean_df['body_mass_g'].std()),
    'mean_flipper_length_mm': float(clean_df['flipper_length_mm'].mean()),
    'mean_culmen_length_mm': float(clean_df['culmen_length_mm'].mean()),
    'mean_culmen_depth_mm': float(clean_df['culmen_depth_mm'].mean()),
    'experiment_id': experiment_metadata['experiment_id'],
    'operator': experiment_metadata['operator'],
    'date_completed': experiment_metadata['date_completed'],
}

# Sexual dimorphism
try:
    male_mass = clean_df[clean_df['sex'] == 'Male']['body_mass_g'].mean()
    female_mass = clean_df[clean_df['sex'] == 'Female']['body_mass_g'].mean()
    analysis_results['sexual_dimorphism'] = {
        'male_mean_body_mass_g': float(male_mass),
        'female_mean_body_mass_g': float(female_mass),
        'dimorphism_ratio': float(male_mass / female_mass),
    }
except:
    analysis_results['sexual_dimorphism'] = None

print("Analysis Results (JSON export format):")
print(json.dumps(analysis_results, indent=2))
# Out:
# Analysis Results (JSON export format):
# {
#   "species": "Gentoo",
#   "specimen_count": 30,
#   "specimen_by_sex": {
#     "Male": 18,
#     "Female": 12
#   },
#   "specimen_by_island": {
#     "Biscoe": 30
#   },
#   "mean_body_mass_g": 4564.8,
#   "std_body_mass_g": 223.71077386846525,
#   "mean_flipper_length_mm": 225.63333333333333,
#   "mean_culmen_length_mm": 50.326666666666675,
#   "mean_culmen_depth_mm": 15.63,
#   "experiment_id": "EXP-2026-PENGUIN-003-Gentoo",
#   "operator": "Dr. Maria Okonkwo",
#   "date_completed": "2026-02-06",
#   "sexual_dimorphism": {
#     "male_mean_body_mass_g": 4713.888888888889,
#     "female_mean_body_mass_g": 4341.166666666667,
#     "dimorphism_ratio": 1.0858576163601694
#   }
# }

# %% [markdown]
# ## Results and Conclusions
#
# **Key Findings for Gentoo Penguins:**
#
# - Total specimens analyzed: [from data]
# - Distribution by sex: [male/female/unknown counts]
# - Distribution by island: [Torgersen/Biscoe/Dream]
# - Clear sexual dimorphism with males larger than females
# - Geographic variation noted between islands
#
# **Quality Assurance:**
# - ✓ Data loaded and validated
# - ✓ No critical missing values
# - ✓ Statistical calculations complete
#
# **Sign-Off:**
# - Analyst: Dr. Maria Okonkwo
# - Date: 2026-02-06
# - Status: Complete - ready for aggregation

# %%
# Create export package for aggregation
export_package = {
    'metadata': experiment_metadata,
    'analysis_results': analysis_results,
    'specimen_count': len(clean_df),
    'export_timestamp': datetime.now().isoformat(),
    'notebook_version': '1.0'
}

print("Export package ready for ELN_results.ipynb")
print(f"Species: {analysis_results['species']}")
print(f"Specimens: {analysis_results['specimen_count']}")
print(f"Timestamp: {export_package['export_timestamp']}")
# Out:
# Export package ready for ELN_results.ipynb
# Species: Gentoo
# Specimens: 30
# Timestamp: 2026-02-09T16:22:23.932131
